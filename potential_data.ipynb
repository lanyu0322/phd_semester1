# %% [markdown]
# <a href="https://colab.research.google.com/github/lanyu0322/phd_semester1/blob/master/potential_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# -- mount google drive
from google.colab import drive
drive.mount("/content/drive")

# -- install geopandas
# !pip install geopandas
# !pip install gmaps
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive
# ...
#      |████████████████████████████████| 921kB 4.9MB/s
# ...
#      |████████████████████████████████| 10.1MB 45.4MB/s
# ...
#      |████████████████████████████████| 11.8MB 196kB/s
# ...
#      |████████████████████████████████| 1.1MB 4.9MB/s
# ...
#   Created wheel for gmaps: filename=gmaps-0.9.0-py2.py3-none-any.whl size=2076097 sha256=d3070eb0b67c1757ea41135db616c23ac5e2d6e5b891ca5a24b765fafd269223
# ...

# %%
import os
import time
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import geopandas as gp
from shapely.geometry import Point

# %% [markdown]
# https://data.cityofnewyork.us/Recreation/Directory-of-Eateries/8792-ebcp
# Eateries in in New York City Department of Parks & Recreation properties including snack bars, food carts, mobile food trucks, and restaurants.

# %%
# -- read the data
fname = os.path.join("drive", "My Drive", "lwir", "data", "food_truck", "DPR_Eateries_001.json")
foodtruck = pd.read_json(fname)

# %%
foodtruck.head()
# Out:
#                      name  ...  type_name
# 0  Central Park Food Cart  ...  Food Cart
# 1  Central Park Food Cart  ...  Food Cart
# 2  Central Park Food Cart  ...  Food Cart
# 3  Central Park Food Cart  ...  Food Cart
# 4  Central Park Food Cart  ...  Food Cart
#
# [5 rows x 10 columns]

# %%
len(foodtruck)

# %% [markdown]
# https://data.cityofnewyork.us/Housing-Development/Directory-of-Concessions/ac9y-je94   This is the concessions currently operate in parks

# %%
# -- read the data
fname = os.path.join("drive", "My Drive", "lwir", "data", "food_truck", "DPR_Concessions_001.json")
concessions = pd.read_json(fname)

# %%
concessions.head()
#len(concessions)
# Out:
#                           name  ...                                          locations
# 0       Alley Pond Golf Center  ...  {'location': [{'lat': '40.765294', 'lng': '-73...
# 1     Alley Pond Tennis Center  ...  {'location': [{'lat': '40.739339', 'lng': '-73...
# 2  Arthur Kill Road Restaurant  ...  {'location': [{'lat': '40.561066', 'lng': '-74...
# 3       Astoria Pool Snack Bar  ...  {'location': [{'lat': '40.779108', 'lng': '-73...
# 4   Battery Gardens Restaurant  ...  {'location': [{'lat': '40.701423', 'lng': '-74...
#
# [5 rows x 12 columns]

# %% [markdown]
# Sidewalk Café Licenses and ApplicationsBusiness
# https://data.cityofnewyork.us/Business/Sidewalk-Caf-Licenses-and-Applications/qcdj-rwhu

# %%
# -- read the data
fname = os.path.join("drive", "My Drive", "lwir", "data", "food_truck", "Sidewalk_Caf__Licenses_and_Applications.csv")
cafe = pd.read_csv(fname)

# %%
cafe.head()
# Out:
#    LICENSE_NBR LIC_STATUS  ...        ISSUANCE ISSUANCE_DD
# 0  1190049-DCA     Active  ...  Pending Review         NaN
# 1  2055726-DCA   Inactive  ...          Issued  10/17/2017
# 2  2071246-DCA     Active  ...          Issued  09/04/2018
# 3  2055194-DCA     Active  ...          Issued  08/07/2017
# 4  1468273-DCA     Active  ...  Pending Review         NaN
#
# [5 rows x 47 columns]

# %% [markdown]
# https://data.cityofnewyork.us/Health/DOHMH-New-York-City-Restaurant-Inspection-Results/43nn-pn8j
# **DOHMH New York City Restaurant Inspection Results
# only restaurants in an active status are included in the dataset(restaurants and college cafeteria).**

# %%
# -- read the data
fname = os.path.join("drive", "My Drive", "lwir", "data", "food_truck", "DOHMH_New_York_City_Restaurant_Inspection_Results.csv")
restaurants = pd.read_csv(fname)
restaurants.head()
# Out:
#       CAMIS                    DBA       BORO  ...        BIN           BBL   NTA
# 0  50014069            RED LOBSTER  Manhattan  ...  1089941.0  1.019310e+09  MN11
# 1  50000419            NATUREWORKS  Manhattan  ...  1034820.0  1.012710e+09  MN17
# 2  50052197           TERRACE WEST   Brooklyn  ...  3189655.0  3.070710e+09  BK21
# 3  50063522              CECCONI'S   Brooklyn  ...  3000019.0  3.000260e+09  BK38
# 4  50087131  VICTORIA G'S PIZZERIA     Queens  ...  4437647.0  4.031760e+09  QN19
#
# [5 rows x 26 columns]

# %% [markdown]
# https://www2.census.gov/programs-surveys/cbp/technical-documentation/records-layouts/2017_record_layouts/county_layout_2017.txt descriptions of cbp
#
# https://www.census.gov/data/datasets/2017/econ/cbp/2017-cbp.html
# **link of County Business Patterns: 2017
# Just find county level**

# %%
# -- read the data
fname = os.path.join("drive", "My Drive", "lwir", "data", "food_truck", "cbp17co.txt")
business_pattern = pd.read_csv(fname)

# %%
business_pattern.head()
# Out:
#    fipstate  fipscty   naics empflag  ... n1000_3  n1000_4 censtate  cencty
# 0         1        1  ------     NaN  ...       N        N       63       1
# 1         1        1  11----     NaN  ...       N        N       63       1
# 2         1        1  113///     NaN  ...       N        N       63       1
# 3         1        1  1133//     NaN  ...       N        N       63       1
# 4         1        1  11331/     NaN  ...       N        N       63       1
#
# [5 rows x 26 columns]

# %% [markdown]
# # subway station entry data http://web.mta.info/developers/sbwy_entrance.**html**
